# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\ancri\\OneDrive\\Documents\\adult.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#Fetch Random Sample From the Dataset (50%)
df.sample(frac=0.50)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 11310   26       Private  210521       HS-grad                9
# 11042   23       Private  157839    Assoc-acdm               12
# 6228    29       Private  152951       HS-grad                9
# 44806   47     Local-gov  154033  Some-college               10
# 7605    40  Self-emp-inc  142030     Bachelors               13
# ...    ...           ...     ...           ...              ...
# 32736   26       Private   58098  Some-college               10
# 28129   40     Local-gov  112362       Masters               14
# 30938   33       Private  237833  Some-college               10
# 39117   28       Private   54042     Assoc-voc               11
# 13045   26       Private  282643       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 11310  Married-civ-spouse       Craft-repair        Husband  White    Male
# ...

# %%
#Check Null Values In The Dataset

# %%
df.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# 48840    0
# 48841    0
# Length: 48842, dtype: int64

# %%
# Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (48842, 15)

# %%
print('The number of rows :', df.shape [0])
print('The number of columns :', df.shape [1])
# Out:
# The number of rows : 48842
# The number of columns : 15

# %%
#Perform Data Cleaning [ Replace '?' with NaN ]

# %%
df.isin(['?']).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
import numpy as np

# %%
df['workclass']=df['workclass'].replace('?', np.nan)
df['occupation']=df['occupation'].replace('?', np.nan)
df['native-country']=df['native-country'].replace('?', np.nan)

# %%
df.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
#Drop all The Missing Values

# %%
var_1 = df.isnull().sum()*100/len(df)

# %%
var_1
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
df.dropna(how='any', inplace = True)

# %%
df.shape
# Out:
# (45222, 15)

# %%
48842-45222
# Out:
# 3620

# %%
#Check For Duplicate Data and Drop Them???????

# %%
dup=df.duplicated().any()

# %%
dup
# Out:
# True

# %%
df.shape
# Out:
# (45222, 15)

# %% [markdown]
# #Drop The Columns education-num, capital-gain, and capital-loss

# %%
#Drop The Columns education-num, capital-gain, and capital-loss
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
#df.drop([ 'capital-gain','capital-loss'], axis = 1, inplace= False)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 5       34       Private  198693          10th       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %%
df['age'].describe()
# Out:
# count    45222.000000
# mean        38.547941
# std         13.217870
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
df['age'].hist()
# Out:
# <Axes: >

# %%
#Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
sum((df['age']>=17) & (df['age']<=48))
# Out:
# 34902

# %%
sum(df['age'].between(17,48))
# Out:
# 34902

# %%
# What is The Distribution of Workclass Column?

# %%
df['workclass'].hist()
# Out:
# <Axes: >

# %%
#. How Many Persons Having Bachelors and Masters Degree?

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df.head(30)
# Out:
#     age         workclass  fnlwgt     education      marital-status  \
# 0    25           Private  226802          11th       Never-married
# 1    38           Private   89814       HS-grad  Married-civ-spouse
# 2    28         Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3    44           Private  160323  Some-college  Married-civ-spouse
# 5    34           Private  198693          10th       Never-married
# 7    63  Self-emp-not-inc  104626   Prof-school  Married-civ-spouse
# 8    24           Private  369667  Some-college       Never-married
# 9    55           Private  104996       7th-8th  Married-civ-spouse
# 10   65           Private  184454       HS-grad  Married-civ-spouse
# 11   36       Federal-gov  212465     Bachelors  Married-civ-spouse
# 12   26           Private   82091       HS-grad       Never-married
# 14   48           Private  279724       HS-grad  Married-civ-spouse
# 15   43           Private  346189       Masters  Married-civ-spouse
# ...

# %%
sum(df['education'].isin(['Bachelors', 'Masters']))
# Out:
# 10084

# %%
 #Replace Salary Values With 0 and 1

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income', 'salary'],
#       dtype='object')

# %%
df.salary
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 5        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: salary, Length: 45222, dtype: object

# %%
df.income
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 5        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 45222, dtype: object

# %%
df.salary.value_counts()
# Out:
# <=50K    34014
# >50K     11208
# Name: salary, dtype: int64

# %%
df.replace(to_replace=['<=50K', '>50K'], value=[0,1], inplace=True)

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 5   34    Private  198693          10th       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country  income  salary
# 0  United-States       0       0
# 1  United-States       0       0
# 2  United-States       1       1
# 3  United-States       1       1
# 5  United-States       0       0

# %%
#Which Workclass Getting The Highest Salary?

# %%
df.groupby('workclass')['salary'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.554070
# Federal-gov         0.390469
# Local-gov           0.295161
# Self-emp-not-inc    0.278978
# State-gov           0.267215
# Private             0.217702
# Without-pay         0.095238
# Name: salary, dtype: float64

# %%
df.groupby('gender') ['salary'].mean().sort_values(ascending=False)
# Out:
# gender
# Male      0.312477
# Female    0.113576
# Name: salary, dtype: float64
